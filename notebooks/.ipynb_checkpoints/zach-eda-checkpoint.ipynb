# %%
# %load_ext autoreload
# %autoreload 2

import random
import pandas
from typing import Dict, List, Tuple, Set
from src.problem import *
from src.round import *
from src.heuristics import *
from src.utils import *
# Out:
# ---------------------------------------------------
# FileNotFoundError Traceback (most recent call last)
# <ipython-input-1-0eb90d75d8e9> in <module>
#       5 import pandas
#       6 from typing import Dict, List, Tuple, Set
# ----> 7 from src.problem import *
#       8 from src.round import *
#       9 from src.heuristics import *
#
# ~/Mobile-Facility/src/problem.py in <module>
#       2 import numpy as np
#       3 from collections import namedtuple
# ----> 4 from src.utils import *
#       5 import time
#       6
#
# ~/Mobile-Facility/src/utils.py in <module>
#      61     return LOCATIONS, data["CLIENT_LOCATIONS"]
#      62
# ---> 63 LOCATIONS, CLIENT_LOCATIONS = read_data_input()
#      64
#      65 def powerset(iterable):
#
# ~/Mobile-Facility/src/utils.py in read_data_input()
#      56
#      57 def read_data_input():
# ---> 58     file = open("data.json", 'r')
#      59     data = json.load(file)
#      60     LOCATIONS = {int(ind): value for ind, value in data["LOCATIONS"].items()}
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.json'

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? n
# Nothing done.

# %%
#usa_va_charlottesville_city_adult_activity_location_assignment_week.csv
adult_df = pandas.read_csv("usa_va_charlottesville_city_adult_activity_location_assignment_week.csv")
adult_df.head()
# Out:
#        hid      pid  activity_number  activity_type  start_time  duration  \
# 0  2208253  5586585                0              1           0     27900
# 1  2208253  5586585                2              2       28800     17100
# 2  2208253  5586585                4              4       46800      1200
# 3  2208253  5586585                6              2       48600     15300
# 4  2208253  5586585                8              1       64800     36000
#
#        lid  longitude   latitude  travel_mode
# 0  1018209 -78.488467  38.043025           -1
# 1    82246 -78.414920  38.157530           -1
# 2    86726 -78.498790  38.139160           -1
# 3    82246 -78.414920  38.157530           -1
# 4  1018209 -78.488467  38.043025           -1

# %%
# What is lid?
HOME_SHIFT=1000000000
adult_df.loc[adult_df.activity_type == 1, "lid"] += HOME_SHIFT
adult_df
# Out:
#              hid      pid  activity_number  activity_type  start_time  \
# 0        2208253  5586585                0              1           0
# 1        2208253  5586585                2              2       28800
# 2        2208253  5586585                4              4       46800
# 3        2208253  5586585                6              2       48600
# 4        2208253  5586585                8              1       64800
# ...          ...      ...              ...            ...         ...
# 1103745  2226628  5627703               39              1      486000
# 1103746  2226628  5627703               40              1      532800
# 1103747  2226628  5627703               42              4      558600
# 1103748  2226628  5627703               44              2      572100
# 1103749  2226628  5627703               46              1      583200
#
#          duration         lid  longitude   latitude  travel_mode
# 0           27900  1001018209 -78.488467  38.043025           -1
# 1           17100       82246 -78.414920  38.157530           -1
# 2            1200       86726 -78.498790  38.139160           -1
# 3           15300       82246 -78.414920  38.157530           -1
# 4           36000  1001018209 -78.488467  38.043025           -1
# ...           ...         ...        ...        ...          ...
# 1103745     46800  1002705996 -78.469097  38.038500           -1
# 1103746     25320  1002705996 -78.469097  38.038500           -1
# 1103747     12240      131949 -78.484510  38.036050           -1
# 1103748     10200      105075 -78.462870  38.021820           -1
# 1103749     21600  1002705996 -78.469097  38.038500           -1
#
# [1103750 rows x 10 columns]

# %%
df = adult_df.groupby(['lid'])['lid'].count().reset_index(name = 'Count').sort_values(['Count'], ascending=False)
df

# %%
print(adult_df[adult_df["pid"]==5627703])
